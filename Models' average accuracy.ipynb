# %% [markdown]
# # <div align="center"><u>Models' average accuracy</u></div>
#
# ## General description of the "Models' average accuracy" file
#
# The following analysis includes just plots (for every model):
#
# ### 1. Metrics Overview:
#
# **Training metrics:**
# - Average training accuracy
# - Average training accuracy's standard deviation
#
# **Evaluation metrics:**
# - Average evaluation accuracy
# - Average evaluation accuracy's standard deviation

# %% [markdown]
# ##############################################################################################################################

# %% [markdown]
# ###  Import some useful libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %% [markdown]
# ### Suppress warnings

# %%
# import warnings

# # To suppress all warnings
# warnings.filterwarnings("ignore")

# %% [markdown]
# # <div align="center"><u> 1. Metrics overview </u>

# %% [markdown]
# ## <div align="center"><u> Training metrics </u>

# %% [markdown]
# ## <div align="center"><u> Average training accuracy </u>

# %% [markdown]
# ### Store the average training accuracy

# %%
# Store the average training accuracy
averageTrainingAccuracy = {
    "k=3 - Version 1": 0.9929,
    "k=3 - Version 2": 0.9708,
    "k=3 - Version 3": 0.9252,
    "k=3 - Version 4": 0.8405,
    "k=5 - Version 1": 0.9927,
    "k=5 - Version 2": 0.9680,
    "k=5 - Version 3": 0.9012,
    "k=5 - Version 4": 0.7931,
    "k=9 - Version 1": 0.9897,
    "k=9 - Version 2": 0.9665,
    "k=9 - Version 3": 0.8771,
    "k=9 - Version 4": 0.7576,
    "k=11 - Version 1": 0.9897,
    "k=11 - Version 2": 0.9650,
    "k=11 - Version 3": 0.8656,
    "k=11 - Version 4": 0.7504,
}

# %% [markdown]
# ### Extract names and values

# %%
# Extract names and values
averageTrainingAccuracyNames = list(averageTrainingAccuracy.keys())
averageTrainingAccuracyValues = list(averageTrainingAccuracy.values())

# %% [markdown]
# ### Plot average training accuracy

# %%
# Plot the barchart
plt.figure(figsize=(8, 6))
bars = plt.bar(averageTrainingAccuracyNames, averageTrainingAccuracyValues, color='black', width=0.1)
plt.ylabel("Average training accuracy", fontsize = 10)
plt.title("Models' average training accuracy", fontsize = 12)
plt.xticks(rotation=90, ha='right', fontsize = 10)  # Rotate labels for better readability

# Set y-axis limit (adjust max as needed to fit text)
plt.ylim(0, 1.4)

# Add value labels on top of each bar
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, height + 0.05, f'{height:.4f}',
             ha='center', va='bottom', fontsize=8, rotation=90)


plt.tight_layout()
plt.show()

# %% [markdown]
# ### Sort average training accuracy in ascending order

# %%
# Sort by values (ascending)
sorted_averageTrainingAccuracy = dict(sorted(averageTrainingAccuracy.items(), key=lambda item: item[1]))

# %% [markdown]
# ### Extract sorted names and values

# %%
# Extract sorted names and values
sorted_averageTrainingAccuracyNames = list(sorted_averageTrainingAccuracy.keys())
sorted_averageTrainingAccuracyValues = list(sorted_averageTrainingAccuracy.values())

# %% [markdown]
# ### Plot sorted average training accuracy

# %%
# Plot the barchart
plt.figure(figsize=(8, 6))
bars = plt.bar(sorted_averageTrainingAccuracyNames, sorted_averageTrainingAccuracyValues, color='black', width=0.1)
plt.ylabel("Average training accuracy", fontsize = 10)
plt.title("Models' average training accuracy - Sorted", fontsize = 12)
plt.xticks(rotation=90, ha='right', fontsize = 10)  # Rotate labels for better readability

# Set y-axis limit (adjust max as needed to fit text)
plt.ylim(0, 1.4)

# Add value labels on top of each bar
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, height + 0.05, f'{height:.4f}',
             ha='center', va='bottom', fontsize=8, rotation=90)


plt.tight_layout()
plt.show()

# %% [markdown]
#  ## <div align="center"><u> Average training accuracy's standard deviation </u>

# %% [markdown]
# ### Store the average training accuracy's standard deviation

# %%
# Store the average training accuracy's standard deviation
averageTrainingAccuracyStd = {
    "k=3 - Version 1": 0.0051,
    "k=3 - Version 2": 0.0092,
    "k=3 - Version 3": 0.0127,
    "k=3 - Version 4": 0.0193,
    "k=5 - Version 1": 0.0045,
    "k=5 - Version 2": 0.0085,
    "k=5 - Version 3": 0.0185,
    "k=5 - Version 4": 0.0182,
    "k=9 - Version 1": 0.0036,
    "k=9 - Version 2": 0.0105,
    "k=9 - Version 3": 0.0190,
    "k=9 - Version 4": 0.0178,
    "k=11 - Version 1": 0.0036,
    "k=11 - Version 2": 0.0094,
    "k=11 - Version 3": 0.0200,
    "k=11 - Version 4": 0.0190,
}

# %% [markdown]
# ### Extract names and values

# %%
# Extract names and values
averageTrainingAccuracyStdNames = list(averageTrainingAccuracyStd.keys())
averageTrainingAccuracyStdValues = list(averageTrainingAccuracyStd.values())

# %% [markdown]
# ### Plot average training accuracy's standard deviation

# %%
# Plot the barchart
plt.figure(figsize=(8, 6))
bars = plt.bar(averageTrainingAccuracyStdNames, averageTrainingAccuracyStdValues, color='black', width=0.1)
plt.ylabel("Average training accuracy's standard deviation", fontsize = 10)
plt.title("Models' average training accuracy's standard deviation", fontsize = 12)
plt.xticks(rotation=90, ha='right', fontsize = 10)  # Rotate labels for better readability

# Set y-axis limit (adjust max as needed to fit text)
plt.ylim(0, 0.025)

# Add value labels on top of each bar
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, height + 0.0005, f'{height:.4f}',
             ha='center', va='bottom', fontsize=8, rotation=90)


plt.tight_layout()
plt.show()

# %% [markdown]
# ### Sort average training accuracy's standard deviation in ascending order

# %%
# Sort by values (ascending)
sorted_averageTrainingAccuracyStd = dict(sorted(averageTrainingAccuracyStd.items(), key=lambda item: item[1]))

# %% [markdown]
# ### Extract sorted names and values

# %%
# Extract sorted names and values
sorted_averageTrainingAccuracyStdNames = list(sorted_averageTrainingAccuracyStd.keys())
sorted_averageTrainingAccuracyStdValues = list(sorted_averageTrainingAccuracyStd.values())

# %% [markdown]
# ### Plot sorted average training accuracy's standard deviation

# %%
# Plot the barchart
plt.figure(figsize=(8, 6))
bars = plt.bar(sorted_averageTrainingAccuracyStdNames, sorted_averageTrainingAccuracyStdValues, color='black', width=0.1)
plt.ylabel("Average training accuracy's standard deviation", fontsize = 10)
plt.title("Models' average training accuracy's standard deviation - Sorted", fontsize = 12)
plt.xticks(rotation=90, ha='right', fontsize = 10)  # Rotate labels for better readability

# Set y-axis limit (adjust max as needed to fit text)
plt.ylim(0, 0.025)

# Add value labels on top of each bar
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, height + 0.0005, f'{height:.4f}',
             ha='center', va='bottom', fontsize=8, rotation=90)


plt.tight_layout()
plt.show()

# %% [markdown]
# ## <div align="center"><u> Evaluation metrics </u>

# %% [markdown]
# ## <div align="center"><u> Average evaluation accuracy </u>

# %% [markdown]
# ### Store the average evaluation accuracy

# %%
# Store the average evaluation accuracy
averageEvaluationAccuracy = {
    "k=3 - Version 1": 0.9920,
    "k=3 - Version 2": 0.9520,
    "k=3 - Version 3": 0.8776,
    "k=3 - Version 4": 0.7320,
    "k=5 - Version 1": 0.9908,
    "k=5 - Version 2": 0.9516,
    "k=5 - Version 3": 0.8700,
    "k=5 - Version 4": 0.7224,
    "k=9 - Version 1": 0.9908,
    "k=9 - Version 2": 0.9552,
    "k=9 - Version 3": 0.8452,
    "k=9 - Version 4": 0.7212,
    "k=11 - Version 1": 0.9908,
    "k=11 - Version 2": 0.9540,
    "k=11 - Version 3": 0.8360,
    "k=11 - Version 4": 0.7176,
}

# %% [markdown]
# ### Extract names and values

# %%
# Extract names and values
averageEvaluationAccuracyNames = list(averageEvaluationAccuracy.keys())
averageEvaluationAccuracyValues = list(averageEvaluationAccuracy.values())

# %% [markdown]
# ### Plot average evaluation accuracy

# %%
# Plot the barchart
plt.figure(figsize=(8, 6))
bars = plt.bar(averageEvaluationAccuracyNames, averageEvaluationAccuracyValues, color='black', width=0.1)
plt.ylabel("Average evaluation accuracy", fontsize = 10)
plt.title("Models' average evaluation accuracy", fontsize = 12)
plt.xticks(rotation=90, ha='right', fontsize = 10)  # Rotate labels for better readability

# Set y-axis limit (adjust max as needed to fit text)
plt.ylim(0, 1.4)

# Add value labels on top of each bar
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, height + 0.1, f'{height:.4f}',
             ha='center', va='bottom', fontsize=8, rotation=90)


plt.tight_layout()
plt.show()

# %% [markdown]
# ### Sort average evaluation accuracy in ascending order

# %%
# Sort by values (ascending)
sorted_averageEvaluationAccuracy = dict(sorted(averageEvaluationAccuracy.items(), key=lambda item: item[1]))

# %% [markdown]
# ### Extract sorted names and values

# %%
# Extract sorted names and values
sorted_averageEvaluationAccuracyNames = list(sorted_averageEvaluationAccuracy.keys())
sorted_averageEvaluationAccuracyValues = list(sorted_averageEvaluationAccuracy.values())

# %% [markdown]
# ### Plot sorted average evaluation accuracy

# %%
# Plot the barchart
plt.figure(figsize=(8, 6))
bars = plt.bar(sorted_averageEvaluationAccuracyNames, sorted_averageEvaluationAccuracyValues, color='black', width=0.1)
plt.ylabel("Average evaluation accuracy", fontsize = 10)
plt.title("Models' average evaluation accuracy - Sorted", fontsize = 12)
plt.xticks(rotation=90, ha='right', fontsize = 10)  # Rotate labels for better readability

# Set y-axis limit (adjust max as needed to fit text)
plt.ylim(0, 1.4)

# Add value labels on top of each bar
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, height + 0.1, f'{height:.4f}',
             ha='center', va='bottom', fontsize=8, rotation=90)


plt.tight_layout()
plt.show()

# %% [markdown]
#  ## <div align="center"><u> Average evaluation accuracy's standard deviation </u>

# %% [markdown]
# ### Store the average evaluation accuracy's standard deviation

# %%
# Store the average evaluation accuracy's standard deviation
averageEvaluationAccuracyStd = {
    "k=3 - Version 1": 0.0098,
    "k=3 - Version 2": 0.0219,
    "k=3 - Version 3": 0.0387,
    "k=3 - Version 4": 0.0520,
    "k=5 - Version 1": 0.0107,
    "k=5 - Version 2": 0.0263,
    "k=5 - Version 3": 0.0342,
    "k=5 - Version 4": 0.0488,
    "k=9 - Version 1": 0.0107,
    "k=9 - Version 2": 0.0255,
    "k=9 - Version 3": 0.0348,
    "k=9 - Version 4": 0.0489,
    "k=11 - Version 1": 0.0107,
    "k=11 - Version 2": 0.0266,
    "k=11 - Version 3": 0.0386,
    "k=11 - Version 4": 0.0473,
}

# %% [markdown]
# ### Extract names and values

# %%
# Extract names and values
averageEvaluationAccuracyStdNames = list(averageEvaluationAccuracyStd.keys())
averageEvaluationAccuracyStdValues = list(averageEvaluationAccuracyStd.values())

# %% [markdown]
# ### Plot average evaluation accuracy's standard deviation

# %%
# Plot the barchart
plt.figure(figsize=(8, 6))
bars = plt.bar(averageEvaluationAccuracyStdNames, averageEvaluationAccuracyStdValues, color='black', width=0.1)
plt.ylabel("Average evaluation accuracy's standard deviation", fontsize = 10)
plt.title("Models' average evaluation accuracy's standard deviation", fontsize = 12)
plt.xticks(rotation=90, ha='right', fontsize = 10)  # Rotate labels for better readability

# Set y-axis limit (adjust max as needed to fit text)
plt.ylim(0, 0.06)

# Add value labels on top of each bar
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, height + 0.001, f'{height:.4f}',
             ha='center', va='bottom', fontsize=8, rotation=90)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Sort average evaluation accuracy's standard deviation in ascending order

# %%
# Sort by values (ascending)
sorted_averageEvaluationAccuracyStd = dict(sorted(averageEvaluationAccuracyStd.items(), key=lambda item: item[1]))

# %% [markdown]
# ### Extract sorted names and values

# %%
# Extract sorted names and values
sorted_averageEvaluationAccuracyStdNames = list(sorted_averageEvaluationAccuracyStd.keys())
sorted_averageEvaluationAccuracyStdValues = list(sorted_averageEvaluationAccuracyStd.values())

# %% [markdown]
# ### Plot sorted average evaluation accuracy's standard deviation

# %%
# Plot the barchart
plt.figure(figsize=(8, 6))
bars = plt.bar(sorted_averageEvaluationAccuracyStdNames, sorted_averageEvaluationAccuracyStdValues, color='black', width=0.1)
plt.ylabel("Average evaluation accuracy's standard deviation", fontsize = 10)
plt.title("Models' average evaluation accuracy's standard deviation - Sorted", fontsize = 12)
plt.xticks(rotation=90, ha='right', fontsize = 10)  # Rotate labels for better readability

# Set y-axis limit (adjust max as needed to fit text)
plt.ylim(0, 0.06)

# Add value labels on top of each bar
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, height + 0.001, f'{height:.4f}',
             ha='center', va='bottom', fontsize=8, rotation=90)

plt.tight_layout()
plt.show()
